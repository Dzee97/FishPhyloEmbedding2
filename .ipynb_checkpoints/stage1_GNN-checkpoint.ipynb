# %%
# Import graph data from preprocessing pipeline into memory
import numpy as np
import pandas as pd

edge_index = np.load("./output/edge_index.npy")      # graph connectivity
edge_weight = np.load("./output/edge_weight.npy")    # branch length
nodes = pd.read_csv("./output/nodes.csv")            # node metadata
